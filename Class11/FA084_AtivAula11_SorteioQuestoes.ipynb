# %% [markdown]
# # FA084 - ATIVIDADE AULA 11
# # "Script" para Sorteio das questões a serem respondidas

# %%
import pandas as pd
import random as rnd
import numpy as np

# %%
# Número de questões (n)
n = 50
# Vetor com n elementos
vetor_n = list(range(1,n+1))

# %%
# Data de Nascimento (SEM 0, se menor que 10)
dia_aniv = 19
mes_aniv = 4
# Primeiro número aleatório
seu_aniv = dia_aniv + mes_aniv

# %%
# RA (SEM 0 iniciais, se for o caso)
seu_RA = 169227

# %%
# Primeira pergunta a responder (R1)
rnd.seed(seu_aniv)
R1 = rnd.randint(1, n)

rnd.seed(seu_RA)
R2 = rnd.randint(1, n)

print('Primeira pergunta:', R1)
print('Segunda pergunta:', R2)
# Out:
# Primeira pergunta: 50
# Segunda pergunta: 36
